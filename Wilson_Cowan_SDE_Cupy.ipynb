# %% [markdown]
# <a href="https://colab.research.google.com/github/charupandey-codes/Modeling-an-fMRI-time-series/blob/main/Wilson_Cowan_SDE_Cupy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install vbi
# Out:
# Collecting vbi
#   Downloading vbi-0.3.tar.gz (34.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.6/34.6 MB 54.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: wheel in /usr/local/lib/python3.12/dist-packages (from vbi) (0.45.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from vbi) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from vbi) (1.16.2)
# Requirement already satisfied: numba in /usr/local/lib/python3.12/dist-packages (from vbi) (0.60.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.12/dist-packages (from vbi) (3.15.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from vbi) (2.2.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from vbi) (3.5)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.12/dist-packages (from vbi) (7.16.6)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from vbi) (3.10.0)
# Collecting setuptools-scm (from vbi)
#   Downloading setuptools_scm-9.2.2-py3-none-any.whl.metadata (7.7 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from vbi) (4.67.1)
# Requirement already satisfied: autograd in /usr/local/lib/python3.12/dist-packages (from vbi) (1.8.0)
# Collecting parameterized (from vbi)
#   Downloading parameterized-0.9.0-py2.py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from vbi) (1.6.1)
# Requirement already satisfied: pytest in /usr/local/lib/python3.12/dist-packages (from vbi) (8.4.2)
# Collecting swig (from vbi)
#   Using cached swig-4.3.1.post0-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (3.5 kB)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from vbi) (13.9.4)
# Collecting corner (from vbi)
#   Downloading corner-2.2.3-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->vbi) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->vbi) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->vbi) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->vbi) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->vbi) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->vbi) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->vbi) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->vbi) (2.9.0.post0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from nbconvert->vbi) (4.13.5)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert->vbi) (6.2.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.12/dist-packages (from nbconvert->vbi) (0.7.1)
# Requirement already satisfied: jinja2>=3.0 in /usr/local/lib/python3.12/dist-packages (from nbconvert->vbi) (3.1.6)
# Requirement already satisfied: jupyter-core>=4.7 in /usr/local/lib/python3.12/dist-packages (from nbconvert->vbi) (5.8.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.12/dist-packages (from nbconvert->vbi) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from nbconvert->vbi) (3.0.3)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.12/dist-packages (from nbconvert->vbi) (3.1.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from nbconvert->vbi) (0.10.2)
# Requirement already satisfied: nbformat>=5.7 in /usr/local/lib/python3.12/dist-packages (from nbconvert->vbi) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from nbconvert->vbi) (1.5.1)
# Requirement already satisfied: pygments>=2.4.1 in /usr/local/lib/python3.12/dist-packages (from nbconvert->vbi) (2.19.2)
# Requirement already satisfied: traitlets>=5.1 in /usr/local/lib/python3.12/dist-packages (from nbconvert->vbi) (5.7.1)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba->vbi) (0.43.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->vbi) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->vbi) (2025.2)
# Requirement already satisfied: iniconfig>=1 in /usr/local/lib/python3.12/dist-packages (from pytest->vbi) (2.1.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.12/dist-packages (from pytest->vbi) (1.6.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->vbi) (4.0.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->vbi) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->vbi) (3.6.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from setuptools-scm->vbi) (75.2.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->vbi) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert->vbi) (1.4.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from jupyter-core>=4.7->nbconvert->vbi) (4.5.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->vbi) (0.1.2)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.12/dist-packages (from nbclient>=0.5.0->nbconvert->vbi) (7.4.9)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.12/dist-packages (from nbformat>=5.7->nbconvert->vbi) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.12/dist-packages (from nbformat>=5.7->nbconvert->vbi) (4.25.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->vbi) (1.17.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->nbconvert->vbi) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->nbconvert->vbi) (4.15.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->vbi) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->vbi) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->vbi) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->vbi) (0.27.1)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert->vbi) (0.4)
# Requirement already satisfied: nest-asyncio>=1.5.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert->vbi) (1.6.0)
# Requirement already satisfied: pyzmq>=23.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert->vbi) (26.2.1)
# Requirement already satisfied: tornado>=6.2 in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert->vbi) (6.5.1)
# Downloading corner-2.2.3-py3-none-any.whl (15 kB)
# Downloading parameterized-0.9.0-py2.py3-none-any.whl (20 kB)
# Downloading setuptools_scm-9.2.2-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.0/63.0 kB 5.0 MB/s eta 0:00:00
# Using cached swig-4.3.1.post0-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.9 MB)
# Building wheels for collected packages: vbi
#   Building wheel for vbi (pyproject.toml) ... done
#   Created wheel for vbi: filename=vbi-0.3-cp312-cp312-linux_x86_64.whl size=10883169 sha256=4731cec41cf87505f61900a62906519c17a62da4378a7fdd15f14a81a80bbbb3
#   Stored in directory: /root/.cache/pip/wheels/14/35/5a/f474753d00953209eb69cf4e82d8c68726efe4fecc5bafa420
# Successfully built vbi
# Installing collected packages: swig, setuptools-scm, parameterized, corner, vbi
# Successfully installed corner-2.2.3 parameterized-0.9.0 setuptools-scm-9.2.2 swig-4.3.1.post0 vbi-0.3

# %%
# !pip install sbi
# Out:
# Collecting sbi
#   Downloading sbi-0.25.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: arviz in /usr/local/lib/python3.12/dist-packages (from sbi) (0.22.0)
# Requirement already satisfied: joblib>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from sbi) (1.5.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from sbi) (3.10.0)
# Collecting notebook<=6.4.12 (from sbi)
#   Downloading notebook-6.4.12-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from sbi) (2.0.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from sbi) (11.3.0)
# Collecting pyknos>=0.16.0 (from sbi)
#   Downloading pyknos-0.16.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting pyro-ppl>=1.3.1 (from sbi)
#   Downloading pyro_ppl-1.9.1-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from sbi) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from sbi) (1.16.2)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.12/dist-packages (from sbi) (2.19.0)
# Collecting torch<2.6.0,>=1.13.0 (from sbi)
#   Downloading torch-2.5.1-cp312-cp312-manylinux1_x86_64.whl.metadata (28 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from sbi) (4.67.1)
# Requirement already satisfied: pymc>=5.0.0 in /usr/local/lib/python3.12/dist-packages (from sbi) (5.25.1)
# Collecting zuko>=1.2.0 (from sbi)
#   Downloading zuko-1.5.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from notebook<=6.4.12->sbi) (3.1.6)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.12/dist-packages (from notebook<=6.4.12->sbi) (6.5.1)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.12/dist-packages (from notebook<=6.4.12->sbi) (26.2.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.12/dist-packages (from notebook<=6.4.12->sbi) (25.1.0)
# Requirement already satisfied: traitlets>=4.2.1 in /usr/local/lib/python3.12/dist-packages (from notebook<=6.4.12->sbi) (5.7.1)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.12/dist-packages (from notebook<=6.4.12->sbi) (5.8.1)
# Requirement already satisfied: jupyter-client>=5.3.4 in /usr/local/lib/python3.12/dist-packages (from notebook<=6.4.12->sbi) (7.4.9)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.12/dist-packages (from notebook<=6.4.12->sbi) (0.2.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.12/dist-packages (from notebook<=6.4.12->sbi) (5.10.4)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.12/dist-packages (from notebook<=6.4.12->sbi) (7.16.6)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.12/dist-packages (from notebook<=6.4.12->sbi) (1.6.0)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.12/dist-packages (from notebook<=6.4.12->sbi) (6.17.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from notebook<=6.4.12->sbi) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.12/dist-packages (from notebook<=6.4.12->sbi) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.12/dist-packages (from notebook<=6.4.12->sbi) (0.23.1)
# Collecting nflows==0.14 (from pyknos>=0.16.0->sbi)
#   Downloading nflows-0.14.tar.gz (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.8/45.8 kB 2.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: cachetools>=4.2.1 in /usr/local/lib/python3.12/dist-packages (from pymc>=5.0.0->sbi) (5.5.2)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.12/dist-packages (from pymc>=5.0.0->sbi) (3.1.1)
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.12/dist-packages (from pymc>=5.0.0->sbi) (2.2.2)
# Requirement already satisfied: pytensor<2.32,>=2.31.7 in /usr/local/lib/python3.12/dist-packages (from pymc>=5.0.0->sbi) (2.31.7)
# Requirement already satisfied: rich>=13.7.1 in /usr/local/lib/python3.12/dist-packages (from pymc>=5.0.0->sbi) (13.9.4)
# Requirement already satisfied: threadpoolctl<4.0.0,>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from pymc>=5.0.0->sbi) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.12/dist-packages (from pymc>=5.0.0->sbi) (4.15.0)
# Requirement already satisfied: setuptools>=60.0.0 in /usr/local/lib/python3.12/dist-packages (from arviz->sbi) (75.2.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from arviz->sbi) (25.0)
# Requirement already satisfied: xarray>=2023.7.0 in /usr/local/lib/python3.12/dist-packages (from arviz->sbi) (2025.10.1)
# Requirement already satisfied: h5netcdf>=1.0.2 in /usr/local/lib/python3.12/dist-packages (from arviz->sbi) (1.6.4)
# Requirement already satisfied: xarray-einstats>=0.3 in /usr/local/lib/python3.12/dist-packages (from arviz->sbi) (0.9.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->sbi) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->sbi) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->sbi) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->sbi) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->sbi) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->sbi) (2.9.0.post0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from pyro-ppl>=1.3.1->sbi) (3.4.0)
# Collecting pyro-api>=0.1.1 (from pyro-ppl>=1.3.1->sbi)
#   Downloading pyro_api-0.1.2-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch<2.6.0,>=1.13.0->sbi) (3.20.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch<2.6.0,>=1.13.0->sbi) (3.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch<2.6.0,>=1.13.0->sbi) (2025.3.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch<2.6.0,>=1.13.0->sbi)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch<2.6.0,>=1.13.0->sbi)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch<2.6.0,>=1.13.0->sbi)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch<2.6.0,>=1.13.0->sbi)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch<2.6.0,>=1.13.0->sbi)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch<2.6.0,>=1.13.0->sbi)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch<2.6.0,>=1.13.0->sbi)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch<2.6.0,>=1.13.0->sbi)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch<2.6.0,>=1.13.0->sbi)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.21.5 (from torch<2.6.0,>=1.13.0->sbi)
#   Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.4.127 (from torch<2.6.0,>=1.13.0->sbi)
#   Downloading nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch<2.6.0,>=1.13.0->sbi)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting triton==3.1.0 (from torch<2.6.0,>=1.13.0->sbi)
#   Downloading triton-3.1.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.3 kB)
# Collecting sympy==1.13.1 (from torch<2.6.0,>=1.13.0->sbi)
#   Downloading sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy==1.13.1->torch<2.6.0,>=1.13.0->sbi) (1.3.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.12/dist-packages (from tensorboard->sbi) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.12/dist-packages (from tensorboard->sbi) (1.75.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard->sbi) (3.9)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.12/dist-packages (from tensorboard->sbi) (5.29.5)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.12/dist-packages (from tensorboard->sbi) (1.17.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard->sbi) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard->sbi) (3.1.3)
# Requirement already satisfied: h5py in /usr/local/lib/python3.12/dist-packages (from h5netcdf>=1.0.2->arviz->sbi) (3.15.0)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=5.3.4->notebook<=6.4.12->sbi) (0.4)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from jupyter-core>=4.6.1->notebook<=6.4.12->sbi) (4.5.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook<=6.4.12->sbi) (4.13.5)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook<=6.4.12->sbi) (6.2.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook<=6.4.12->sbi) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook<=6.4.12->sbi) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook<=6.4.12->sbi) (3.0.3)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook<=6.4.12->sbi) (3.1.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook<=6.4.12->sbi) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook<=6.4.12->sbi) (1.5.1)
# Requirement already satisfied: pygments>=2.4.1 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook<=6.4.12->sbi) (2.19.2)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.12/dist-packages (from nbformat->notebook<=6.4.12->sbi) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.12/dist-packages (from nbformat->notebook<=6.4.12->sbi) (4.25.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.24.0->pymc>=5.0.0->sbi) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.24.0->pymc>=5.0.0->sbi) (2025.2)
# Requirement already satisfied: etuples in /usr/local/lib/python3.12/dist-packages (from pytensor<2.32,>=2.31.7->pymc>=5.0.0->sbi) (0.3.10)
# Requirement already satisfied: logical-unification in /usr/local/lib/python3.12/dist-packages (from pytensor<2.32,>=2.31.7->pymc>=5.0.0->sbi) (0.4.6)
# Requirement already satisfied: miniKanren in /usr/local/lib/python3.12/dist-packages (from pytensor<2.32,>=2.31.7->pymc>=5.0.0->sbi) (1.0.5)
# Requirement already satisfied: cons in /usr/local/lib/python3.12/dist-packages (from pytensor<2.32,>=2.31.7->pymc>=5.0.0->sbi) (0.4.7)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.7.1->pymc>=5.0.0->sbi) (4.0.0)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.12/dist-packages (from terminado>=0.8.3->notebook<=6.4.12->sbi) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.12/dist-packages (from argon2-cffi->notebook<=6.4.12->sbi) (25.1.0)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel->notebook<=6.4.12->sbi) (1.8.15)
# Requirement already satisfied: ipython>=7.23.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel->notebook<=6.4.12->sbi) (7.34.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel->notebook<=6.4.12->sbi) (0.1.7)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from ipykernel->notebook<=6.4.12->sbi) (5.9.5)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=5->notebook<=6.4.12->sbi) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook<=6.4.12->sbi) (1.4.0)
# Collecting jedi>=0.16 (from ipython>=7.23.1->ipykernel->notebook<=6.4.12->sbi)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel->notebook<=6.4.12->sbi) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel->notebook<=6.4.12->sbi) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel->notebook<=6.4.12->sbi) (3.0.52)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel->notebook<=6.4.12->sbi) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel->notebook<=6.4.12->sbi) (4.9.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->notebook<=6.4.12->sbi) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->notebook<=6.4.12->sbi) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->notebook<=6.4.12->sbi) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->notebook<=6.4.12->sbi) (0.27.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.7.1->pymc>=5.0.0->sbi) (0.1.2)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook<=6.4.12->sbi) (2.0.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->nbconvert>=5->notebook<=6.4.12->sbi) (2.8)
# Requirement already satisfied: toolz in /usr/local/lib/python3.12/dist-packages (from logical-unification->pytensor<2.32,>=2.31.7->pymc>=5.0.0->sbi) (0.12.1)
# Requirement already satisfied: multipledispatch in /usr/local/lib/python3.12/dist-packages (from logical-unification->pytensor<2.32,>=2.31.7->pymc>=5.0.0->sbi) (1.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook<=6.4.12->sbi) (2.23)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->notebook<=6.4.12->sbi) (0.8.5)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.23.1->ipykernel->notebook<=6.4.12->sbi) (0.2.14)
# Downloading sbi-0.25.0-py3-none-any.whl (459 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 460.0/460.0 kB 22.8 MB/s eta 0:00:00
# Downloading notebook-6.4.12-py3-none-any.whl (9.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 117.5 MB/s eta 0:00:00
# Downloading pyknos-0.16.0-py3-none-any.whl (13 kB)
# Downloading pyro_ppl-1.9.1-py3-none-any.whl (755 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 756.0/756.0 kB 39.4 MB/s eta 0:00:00
# Downloading torch-2.5.1-cp312-cp312-manylinux1_x86_64.whl (906.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 906.4/906.4 MB 821.2 kB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 100.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 87.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 41.8 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.0 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 8.8 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.2 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.8 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl (188.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 7.5 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 66.5 MB/s eta 0:00:00
# Downloading nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 6.2 MB/s eta 0:00:00
# Downloading sympy-1.13.1-py3-none-any.whl (6.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 85.0 MB/s eta 0:00:00
# Downloading triton-3.1.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (209.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.6/209.6 MB 6.1 MB/s eta 0:00:00
# Downloading zuko-1.5.0-py3-none-any.whl (47 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.4/47.4 kB 3.0 MB/s eta 0:00:00
# Downloading pyro_api-0.1.2-py3-none-any.whl (11 kB)
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 63.4 MB/s eta 0:00:00
# Building wheels for collected packages: nflows
#   Building wheel for nflows (setup.py) ... done
#   Created wheel for nflows: filename=nflows-0.14-py3-none-any.whl size=53654 sha256=7cd141a115f83ea5ccbd56e1cd1c58c5ebc5e2423a720a420819f6db34ff4ff6
#   Stored in directory: /root/.cache/pip/wheels/fd/27/c3/8952205ea17b63dc1eaa24031e63111c6a3661cb22cc1e2a3c
# Successfully built nflows
# Installing collected packages: pyro-api, triton, sympy, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, jedi, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torch, zuko, pyro-ppl, nflows, pyknos, notebook, sbi
#   Attempting uninstall: triton
#     Found existing installation: triton 3.4.0
#     Uninstalling triton-3.4.0:
#       Successfully uninstalled triton-3.4.0
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.13.3
#     Uninstalling sympy-1.13.3:
#       Successfully uninstalled sympy-1.13.3
#   Attempting uninstall: nvidia-nvtx-cu12
#     Found existing installation: nvidia-nvtx-cu12 12.6.77
#     Uninstalling nvidia-nvtx-cu12-12.6.77:
#       Successfully uninstalled nvidia-nvtx-cu12-12.6.77
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.6.85
#     Uninstalling nvidia-nvjitlink-cu12-12.6.85:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.6.85
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.27.3
#     Uninstalling nvidia-nccl-cu12-2.27.3:
#       Successfully uninstalled nvidia-nccl-cu12-2.27.3
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.7.77
#     Uninstalling nvidia-curand-cu12-10.3.7.77:
#       Successfully uninstalled nvidia-curand-cu12-10.3.7.77
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.3.0.4
#     Uninstalling nvidia-cufft-cu12-11.3.0.4:
#       Successfully uninstalled nvidia-cufft-cu12-11.3.0.4
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.6.77
#     Uninstalling nvidia-cuda-runtime-cu12-12.6.77:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.6.77
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.6.77
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.6.77:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.6.77
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.6.80
#     Uninstalling nvidia-cuda-cupti-cu12-12.6.80:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.6.80
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.6.4.1
#     Uninstalling nvidia-cublas-cu12-12.6.4.1:
#       Successfully uninstalled nvidia-cublas-cu12-12.6.4.1
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.4.2
#     Uninstalling nvidia-cusparse-cu12-12.5.4.2:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.4.2
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.10.2.21
#     Uninstalling nvidia-cudnn-cu12-9.10.2.21:
#       Successfully uninstalled nvidia-cudnn-cu12-9.10.2.21
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.7.1.2
#     Uninstalling nvidia-cusolver-cu12-11.7.1.2:
#       Successfully uninstalled nvidia-cusolver-cu12-11.7.1.2
#   Attempting uninstall: torch
#     Found existing installation: torch 2.8.0+cu126
#     Uninstalling torch-2.8.0+cu126:
#       Successfully uninstalled torch-2.8.0+cu126
#   Attempting uninstall: notebook
#     Found existing installation: notebook 6.5.7
#     Uninstalling notebook-6.5.7:
#       Successfully uninstalled notebook-6.5.7
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.8.0+cu126 requires torch==2.8.0, but you have torch 2.5.1 which is incompatible.
# torchvision 0.23.0+cu126 requires torch==2.8.0, but you have torch 2.5.1 which is incompatible.
# Successfully installed jedi-0.19.2 nflows-0.14 notebook-6.4.12 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nccl-cu12-2.21.5 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.4.127 pyknos-0.16.0 pyro-api-0.1.2 pyro-ppl-1.9.1 sbi-0.25.0 sympy-1.13.1 torch-2.5.1 triton-3.1.0 zuko-1.5.0

# %%
import os
import vbi
import torch
import numpy as np
import networkx as nx
from copy import deepcopy
import sbi.utils as utils
from scipy.signal import welch
import matplotlib.pyplot as plt
from sbi.analysis import pairplot
from vbi.sbi_inference import Inference
from vbi.models.cupy.wilson_cowan import WC_sde

import warnings
warnings.filterwarnings("ignore")

# %%
seed = 42
np.random.seed(seed)

# %%
LABESSIZE = 10
plt.rcParams['axes.labelsize'] = LABESSIZE
plt.rcParams['xtick.labelsize'] = LABESSIZE
plt.rcParams['ytick.labelsize'] = LABESSIZE

# %%
ns = 30
P = np.zeros((2,ns))
values = np.linspace(0,3,ns)
P[0, :] = values
P[1, :] = values
weights = np.array([[0,1],[1,0]], dtype=np.float32)

par = {
    "g_e": 0.0,
    "seed": 42,
    "dt": 0.1,
    "t_end": 2000.0,
    "t_cut": 101.0,
    "noise_amp": 0.001,
    "decimate": 1,
    "P": P,
    "num_sim": ns,
    "RECORD_EI": "EI",
    "engine": "cpu",
    "weights": weights,
    "dtype": "float32",
    "same_initial_state": False,
}

# %%
obj = WC_sde(par)
sol = obj.run()
t = sol["t"]
E = sol["E"]
I = sol["I"]
print(t.shape, E.shape, I.shape)
# Out:
# Integrating: 100%|██████████| 20000/20000 [00:03<00:00, 5197.04it/s]
# (18989,) (18989, 2, 30) (18989, 2, 30)

# %%
f, P_E = welch(E[:, 0, :], fs=1/(par["dt"]*par['decimate']) * 1000, nperseg=8*1024, axis=0)

mosaic = """
AA
BC
"""
fig = plt.figure(constrained_layout=True, figsize=(10, 5))
ax = fig.subplot_mosaic(mosaic)

colors = plt.cm.Reds(np.linspace(0.1,1.0, ns))
for i in range(ns):
    ax['A'].plot(t, E[:, 0, i], alpha=0.5, lw=0.5, color=colors[i])

for i in range(ns):
    ax['B'].plot(f, P_E[:, i], alpha=0.5, lw=1, color=colors[i], label=f"{P[0,i]:.2f}")

for i in range(ns):
    ax['C'].plot(E[:,0,i], I[:,0, i], lw=0.1, alpha=0.5, color=colors[i])

ax['B'].set_xlabel("Frequency")
ax['B'].set_ylabel("Power")
ax['B'].set_xlim(0, 100)
ax['C'].set_xlabel("E")
ax['C'].set_ylabel("I")
# ax['B'].legend(ncol=2)
plt.tight_layout()

# %%
idx_max = np.argmax(P_E, axis=0)
fmax = f[idx_max]
fig, ax = plt.subplots(1, figsize=(5,3))
ax.plot(values, fmax, "bo", ms=10, alpha=0.5)
ax.grid(True, ls='--', lw=0.5)
ax.set_xlabel("P")
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.set_ylabel(r"fmax");

# %%
weights = np.array([[0,1],[1,0]], dtype=np.float32)
P = 1.025

par = {
    "g_e": 0.0,
    "seed": 42,
    "dt": 0.05,
    "t_end": 2000.0,
    "t_cut": 101.0,
    "noise_amp": 0.0005, # add small amount of noise
    "decimate": 1,
    "P": P,
    "num_sim": 1,
    "RECORD_EI": "EI",
    "engine": "cpu",
    "weights": weights,
    "dtype": "float32",
    "same_initial_state": False,
}

obj = WC_sde(par)
sol = obj.run()
t = sol["t"]
E = sol["E"]
I = sol["I"]

f, P_E = welch(E[:, :, 0], fs=1/(par["dt"]*par['decimate']) * 1000, nperseg=5*1024, axis=0)
f, P_I = welch(I[:, :, 0], fs=1/(par["dt"]*par['decimate']) * 1000, nperseg=5*1024, axis=0)

mosaic = """
AA
BC
"""
fig = plt.figure(constrained_layout=True, figsize=(10, 5))
ax = fig.subplot_mosaic(mosaic)

ax['A'].plot(t, E[:, 0, 0], label="E", color="red", alpha=1, lw=0.5)
ax['A'].plot(t, I[:, 0, 0], label="I", color="blue", alpha=1, lw=0.5)
ax['B'].plot(f, P_E[:, 0], label="E", color="red", alpha=1, lw=1)
ax['B'].plot(f, P_I[:, 0], label="I", color="blue", alpha=1, lw=1)
ax['B'].set_xlabel("Frequency")
ax["B"].set_ylabel("Power")
ax['B'].set_xlim(0, 100)
ax['C'].plot(E[:, 0, 0], I[:, 0, 0], lw=0.5)
ax['C'].set_xlabel("E")
ax['C'].set_ylabel("I");

f_max = f[np.argmax(P_E[:,0])]
ax['B'].legend([f"fmax={f_max:.2f}"])
plt.tight_layout()
# Out:
# Integrating: 100%|██████████| 40000/40000 [00:06<00:00, 5869.65it/s]

# %% [markdown]
# Whole brain connectome

# %% [markdown]
# D = vbi.LoadSample(nn=88)
# weights = D.get_weights()
# nn = weights.shape[0]
# print(f"number of nodes: {nn}")

# %%
D = vbi.LoadSample(nn=88)
weights = D.get_weights()
nn = weights.shape[0]
print(f"number of nodes: {nn}")
# Out:
# number of nodes: 88

# %%
g_e = np.array([0.6])
par = {
    "g_e": g_e,
    "seed": 42,
    "dt": 0.1,
    "t_end": 1000.0,
    "t_cut": 101.0,
    "noise_amp": 0.002,
    "decimate": 1,
    "P": 1.,
    "num_sim": len(g_e),
    "RECORD_EI": "EI",
    "engine": "cpu",
    "weights": weights,
    "dtype": "float32",
    "same_initial_state": False,
}

# %%
obj = WC_sde(par)
sol = obj.run()
# print(obj)
# Out:
# Integrating: 100%|██████████| 10000/10000 [00:04<00:00, 2190.22it/s]

# %%
t = sol["t"]
E = sol["E"]
I = sol["I"]
print(t.shape, E.shape, I.shape)

f, P_E = welch(E[:, :, 0], fs=1/(par["dt"]*par['decimate']) * 1000, nperseg=5*1024, axis=0)
f, P_I = welch(I[:, :, 0], fs=1/(par["dt"]*par['decimate']) * 1000, nperseg=5*1024, axis=0)


mosaic = """
AAB
CCB
DEB
"""
fig = plt.figure(constrained_layout=True, figsize=(12, 5))
ax_dict = fig.subplot_mosaic(mosaic)
ax = [ax_dict[key] for key in ax_dict]

ax[0].plot(t, E[:, :, 0], label="E", color="red", alpha=0.1, lw=0.5)
ax[2].plot(t, I[:, :, 0], label="I", color="blue", alpha=0.1, lw=0.5)
ax[3].plot(t, E[:, 0, 0], label="E", color="red", lw=0.5)
ax[3].plot(t, I[:, 0, 0], label="I", color="blue", lw=0.5)
ax[3].legend()
ax[4].plot(E[:, 0, 0], I[:, 0, 0], lw=0.5)
ax[4].set_xlabel("E")
ax[4].set_ylabel("I")

# plot power spectrum of E and I at ax[1]
ax[1].plot(f, P_E, label="E", alpha=0.2, lw=1, color="red")
# ax[1].plot(f, P_I, label="I", color="blue", alpha=0.1, lw=1)
ax[1].set_xlabel("Frequency")
ax[1].set_ylabel("Power")
ax[1].set_xlim(0, 100)

plt.show()
# Out:
# (8989,) (8989, 88, 1) (8989, 88, 1)
